# %%
from pyppeteer import launch
from bs4 import BeautifulSoup
import pandas as pd
import asyncio
import asyncio
import sys
import requests
from pprint import pprint
from datetime import time
import importlib

sys.path.append(r"C:\Users\darie\OneDrive - nyu.edu\PyCharm Projects\mishaScraperPrj\Development-Dir\Dev Dir Git\Proxies Dev 12_10_git\proxiesSrc\src")
import ParseJSON

importlib.reload(ParseJSON)
import pandas as pd
import numpy as np
import Zillow
importlib.reload(Zillow)
from Zillow import Zillow
import json
import requests
from bs4 import BeautifulSoup
import Main
importlib.reload(Main)
import time

# %%
'''
curl -x pr.oxylabs.io:7777 -U customer-darien:Amrikor11 https://ip.oxylabs.io

curl -x pr.oxylabs.io:7777 -U customer-scatw2022116dan9232:ZjkawIChtB https://ip.oxylabs.io   THIS ONE Trial acc
 

curl --user ":" 'https://realtime.oxylabs.io/v1/queries' -H "Content-Type: application/json" -d '{"source": "universal", "url": "https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html", "geo-location": "United States"}'
'''
# Out:
# '\ncurl -x pr.oxylabs.io:7777 -U customer-darien:Amrikor11 https://ip.oxylabs.io\n\ncurl -x pr.oxylabs.io:7777 -U customer-scatw2022116dan9232:ZjkawIChtB https://ip.oxylabs.io   THIS ONE Trial acc\n \n\ncurl --user ":" \'https://realtime.oxylabs.io/v1/queries\' -H "Content-Type: application/json" -d \'{"source": "universal", "url": "https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html", "geo-location": "United States"}\'\n'

# %%
storage = []

# %%
storage
# Out:
# []

# %%
def sendRequest(self, url):
        try:
            payload = {
                        "source": "universal",
                        "url": "https://www.zillow.com/nj/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22usersSearchTerm%22%3A%22NJ%22%2C%22mapBounds%22%3A%7B%22west%22%3A-76.7952458515625%2C%22east%22%3A-72.6534001484375%2C%22south%22%3A38.68416008936318%2C%22north%22%3A41.45789958695567%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A40%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22mp%22%3A%7B%22min%22%3A1436%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22price%22%3A%7B%22min%22%3A300000%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A8%7D", 
                        "geo-location": "United States"        
                        #"render": "html", # If page type requires
                      }
            r = requests.request(
                        'POST',
                        'https://realtime.oxylabs.io/v1/queries',
                        auth=('scatw2022116dan9232', 'ZjkawIChtB'), #Your credentials go here
                        json=payload,
                    )
        
            self.soup = BeautifulSoup(r.content, 'html.parser')  
            if self.captchaCheck(self.soup) is True:
                return sys.exit("CAPTCHA BLOCKED ON FIRST TRY. TRYING AGAIN WITH DIFFERENT HEADERS")
            return self.soup
        except:
            sys.exit("Issue with request")

# %%
def captchaCheck(soup=None):
        if soup: 
            soup = soup
        try:
            text = soup.find(class_="zsg-layout-content").find('div').find('div').text
            if text == "Please verify you're a human to continue.":
                print(text)
                raise Exception(text)
        except:
            return False

# %%
def sendRequest(url):
        try:
            payload = {
                        "source": "universal",
                        "url": url ,
                        "geo-location": "United States"        
                        #"render": "html", # If page type requires
                      }
            r = requests.request(
                        'POST',
                        'https://realtime.oxylabs.io/v1/queries',
                        auth=('scatw2022116dan9232', 'ZjkawIChtB'), #Your credentials go here
                        json=payload,
                    )
           # soup = BeautifulSoup(r['content'], 'html.parser') 
            soup = BeautifulSoup(r.json()['results'][0]['content'], "html.parser") 
            
            if captchaCheck(soup) is True:
                return sys.exit("CAPTCHA BLOCKED ON FIRST TRY. TRYING AGAIN WITH DIFFERENT HEADERS")
            return soup
        except:
            sys.exit("Issue with request")

# %%
link = 'https://www.zillow.com/nj/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22usersSearchTerm%22%3A%22NJ%22%2C%22mapBounds%22%3A%7B%22west%22%3A-76.7952458515625%2C%22east%22%3A-72.6534001484375%2C%22south%22%3A38.68416008936318%2C%22north%22%3A41.45789958695567%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A40%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22mp%22%3A%7B%22min%22%3A1436%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22price%22%3A%7B%22min%22%3A300000%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A8%7D'

storage.append(sendRequest(link).json()['results'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [23], line 3
#       1 link = 'https://www.zillow.com/nj/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22usersSearchTerm%22%3A%22NJ%22%2C%22mapBounds%22%3A%7B%22west%22%3A-76.7952458515625%2C%22east%22%3A-72.6534001484375%2C%22south%22%3A38.68416008936318%2C%22north%22%3A41.45789958695567%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A40%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22mp%22%3A%7B%22min%22%3A1436%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22price%22%3A%7B%22min%22%3A300000%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A8%7D'
# ----> 3 storage.append(sendRequest(link).json()['results'][0])
#
# NameError: name 'sendRequest' is not defined

# %%
r = sendRequest(link)
r

# %%
req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.8',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951 Safari/537.36'
        }
req_headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.9',
            'cookie': 'zguid=23|%24ca6368b9-7b92-4d51-ab67-c2be89065efd; _ga=GA1.2.1460486079.1621047110; _pxvid=7fa13d96-b528-11eb-9860-0242ac120012; _gcl_au=1.1.2025797213.1621047113; __gads=ID=66253ab863481044:T=1621047113:S=ALNI_MZr3mehwm2Wjo7NOrmalVtEcJSXag; __pdst=50987f626deb4767a53b5d8ca2ea406a; _fbp=fb.1.1621047115574.1019382068; _pin_unauth=dWlkPU5EVm1PRGRpTVRBdE5UTTFaUzAwWlRBNExUZzJZall0TWpZMU1HWTBNV0ppWlRkbA; G_ENABLED_IDPS=google; userid=X|3|231a9d744e104379%7C3%7CiEt8bkUx9hWaFeyCeAwN9tHl_T0d0Cq-kynGuEvNYr4%3D; loginmemento=1|c2274ba4a4ad76bbe89263d30695c182e9177b9c40a2691f3054987d66a944be; zjs_user_id=%22X1-ZU158jhpb2klds9_4wzn7%22; zgcus_lbut=; zgcus_aeut=189997416; zgcus_ludi=b44a961b-c7ef-11eb-a48f-96824e7eff50-18999; optimizelyEndUserId=oeu1623111792776r0.8778663892923859; _cs_c=1; WRUIDAWS=3326630244368428; visitor_id701843=248614376; visitor_id701843-hash=4be116fbd77089f953bfb6eaf5996ef92662a6ef7d237d3c49f154ffaf4eaa9295c64fb254b106bdff234e183c94498c01af2aab; __stripe_mid=80125db1-17d1-4fc5-ae37-86b12a68709cf3da6d; g_state={"i_p":1627697570928,"i_l":4}; zjs_anonymous_id=%22ca6368b9-7b92-4d51-ab67-c2be89065efd%22; _gac_UA-21174015-56=1.1626042638.Cj0KCQjwraqHBhDsARIsAKuGZeH8gi095UkXfohW-WWvyLosdmTdL8cfJwgAabYF9hS2XU6JlXqpWLcaAq5SEALw_wcB; _gcl_aw=GCL.1626042640.Cj0KCQjwraqHBhDsARIsAKuGZeH8gi095UkXfohW-WWvyLosdmTdL8cfJwgAabYF9hS2XU6JlXqpWLcaAq5SEALw_wcB; zgsession=1|1edd82e6-372a-4546-bc8b-c2bbadfd29b4; DoubleClickSession=true; fbc=fb.1.1626412984774.IwAR2QM6bzrTskAWN5Sk8UnmPlAxb1HRy1h1GRch888QqXfczHZZWb2vDZfIw; _fbc=fb.1.1626413249162.IwAR2QM6bzrTskAWN5Sk8UnmPlAxb1HRy1h1GRch888QqXfczHZZWb2vDZfIw; _csrf=lV2BBFim7Vy2gFTn--PUt0VA; _gaexp=GAX1.2.w27igyYtRQaAa8XQM3MjDw.18837.2!VDVoDKTnRcyv8f4FAcJ8PA.18915.2!Khnq27RoQmSe5DEusmh5xA.18913.3; _gid=GA1.2.705011419.1630004829; FSsampler=707279376; __CT_Data=gpv=26&ckp=tld&dm=zillow.com&apv_82_www33=26&cpv_82_www33=26&rpv_82_www33=13; OptanonConsent=isIABGlobal=false&datestamp=Fri+Aug+27+2021+12%3A39%3A52+GMT-0600+(Mountain+Daylight+Time)&version=5.11.0&landingPath=NotLandingPage&groups=1%3A1%2C3%3A1%2C4%3A1&AwaitingReconsent=false; _cs_id=41cbdc9c-bb0b-aad9-9521-b1328a65ff77.1623111795.22.1630089665.1630089591.1.1657275795752; utag_main=v_id:01796deff9e3001a59964343177e03079002907100838$_sn:41$_se:2$_ss:0$_st:1630255637884$dc_visit:38$ses_id:1630253822479%3Bexp-session$_pn:1%3Bexp-session$dcsyncran:1%3Bexp-session$tdsyncran:1%3Bexp-session$dc_event:2%3Bexp-session$dc_region:us-east-1%3Bexp-session$ttd_uuid:7b8796ca-44dd-45c9-97d9-bcb642d04cd1%3Bexp-session; JSESSIONID=6CB8C410E0FE216644E8C3A0D0851618; ZILLOW_SID=1|AAAAAVVbFRIBVVsVEklf443J474nftKzJe5PKLD80sujgHvySB7tGcqZunX3BDDH9VwceMqGMTPC54%2F0q4CH%2BfmwsC6P; KruxPixel=true; _derived_epik=dj0yJnU9ai1PSUp1eHZ2Y3J3d0c2NVU1N3BBOFlHbnRBOGFzT0smbj1vLWRISDFwdUNoblN5MjQ4cTVyN213Jm09MSZ0PUFBQUFBR0VzRjRVJnJtPTEmcnQ9QUFBQUFHRXNGNFU; KruxAddition=true; search=6|1632872450375%7Crect%3D40.241821806991595%252C-103.77545313688668%252C39.18758562803622%252C-106.02765040251168%26disp%3Dmap%26mdm%3Dauto%26type%3Dhouse%252Cmultifamily%252Ctownhouse%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%09%0911093%09%09%09%09%09%09; _uetsid=d5e0465006a011ecbe3bd1a0f1c47d01; _uetvid=987e1c70c40a11ebaed8859af36f82fb; _px3=ba45c3df5d5d63d4d9780a102253cd60b21ab52b04778344e332e05474011c21:oCvapPXE6jD0rCXhSf4UjtEC2U956148EDyiWwRFOF8z5vwK63/hC8OWsk09O61g1spnZw64iXApZu1wOmKpyA==:1000:68UzJ5+ar5XwNm61bm41bhSHp8Zp1PfQQlL/5tcqdUIJ3RmA106//vvYGewCCwmln6acqbDAVKgqfB8Th05yX0Cw0TBW7dhfNdeNRjp9bxeLvKqZ56yuW+aVoYYp/zj6MNKv9c16vKlP771xSdCgUTvZ0CDmh7Ng55sHugOHt/jj+2Zmp2WLnuYR4rf7SEndqWBbAyQhhG4BKeyrZyEMpA==; AWSALB=3BIj2fUDeYgoAcLKaZdMkcyTzWSof62v91DQuCssJMyknlpZWcRcVnUU5Me29AcnFcjg1k9H2ehS6N0rSwxo4w8lmEvFCy6hgQfKm1HH8oVoWtpICS36NoLMMxmZ; AWSALBCORS=3BIj2fUDeYgoAcLKaZdMkcyTzWSof62v91DQuCssJMyknlpZWcRcVnUU5Me29AcnFcjg1k9H2ehS6N0rSwxo4w8lmEvFCy6hgQfKm1HH8oVoWtpICS36NoLMMxmZ',
            'referer': 'https://www.google.com/',
            'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
            'sec-ch-ua-mobile': '?1',
            'sec-fetch-dest': 'document',
            'sec-fetch-mode': 'navigate',
            'sec-fetch-site': 'same-origin',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Mobile Safari/537.36'
        }
test_linkNY = 'https://www.zillow.com/ny/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22usersSearchTerm%22%3A%22NY%22%2C%22mapBounds%22%3A%7B%22west%22%3A-79.911886203125%2C%22east%22%3A-71.628194796875%2C%22south%22%3A40.07057084687667%2C%22north%22%3A45.391566871346015%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A43%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22price%22%3A%7B%22min%22%3A300000%7D%2C%22mp%22%3A%7B%22min%22%3A1436%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A7%7D'

# %%
zillow = Zillow()
#soup = zillow.sendRequest('https://www.zillow.com/homedetails/Hampton-Bays-NY-11946/111547925_zpid/')
zillow.parseInputUrl(test_linkNY)
zillow.updateUrlPrice(200000)
zillow.updateUrlPage(4)


#test = zillow.parseAllDataSections(soup)

zillow.url
#r = requests.get(zillow.current_url, headers=req_headers)
zillow.current_url
# Out:
# 'https://www.zillow.com/ny/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A4%7D%2C%22usersSearchTerm%22%3A%22NY%22%2C%22mapBounds%22%3A%7B%22west%22%3A-79.911886203125%2C%22east%22%3A-71.628194796875%2C%22south%22%3A40.07057084687667%2C%22north%22%3A45.391566871346015%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A43%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22price%22%3A%7B%22min%22%3A1%7D%2C%22mp%22%3A%7B%22min%22%3A1436%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A7%7D'

# %%
soup = zillow.sendRequest(zillow.current_url)

# %%
links = zillow.getListingLinks()

# %%
store = []

# %%
stop = 0
for link in links:
    stop+=1
    if stop==5:
        break

    soup = zillow.sendRequest(link)
    if soup is not None:
        payload = zillow.parseAllDataSections(zillow.soup)
        if payload is False:
            print('Error Parsing Data')
            continue
        else:
            store.append(payload)

    else:
        print("request issue")

# %%
store_short = store[:33]

# %%
df1 = zillow.transformRawData(store_short)

# %%
zillow.create_excel(df)

# %%
df['state']
# Out:
# 0     NY
# 1     NY
# 2     NY
# 3     NY
# 4     NY
# 5     NY
# 6     NY
# 7     NY
# 8     NY
# 9     NY
# 10    NY
# 11    NY
# 12    NY
# 13    NY
# 14    NY
# 15    NY
# 16    NY
# 17    NY
# 18    NY
# 19    NY
# 20    NY
# 21    NY
# 22    NY
# 23    NY
# 24    NY
# 25    NY
# 26    NY
# 27    NY
# 28    NY
# 29    NY
# 30    NY
# 31    NY
# 32    NY
# Name: state, dtype: object

# %%
from datetime import date

def create_excel(dataframe):
        path = '../output_data/cleaned_excel/' 
        
        df_og =  dataframe
        params = ['price', 'streetAddress', 'city', 'zipcode','state','daysOnZillow','agentName','agentEmail', 'agentPhoneNumber','hdpUrl']
        df_a = df_og[params]
        df = df_a.sort_values(['agentName','price'],
                    ascending = [False, False])
        try:           
            df = df[~df.agentName.str.contains('Team') ]
        except:
            all = 'good'
        og_len = len(df)
        df_drop = df.drop_duplicates('agentName',ignore_index=True)
        drop_len = len(df_drop)
        df_drop= df_drop.sort_values(['price'],
                    ascending = [False])
        df = df_drop
        df['First'] = df.agentName.apply(
        lambda x: pd.Series(str(x).split(" ")[0]))
        df['agentName']
        
        df['Last'] = df.agentName.apply(
        lambda x: pd.Series(str(x).split("-")[-1].split(' ')[-1]))
        
        cols = [ 'streetAddress', 'price', 'city', 'zipcode', 'state', 'First', 'Last',    'agentEmail', 'agentPhoneNumber', 'daysOnZillow', 'hdpUrl'
        ]
        df = df[cols]
        df.columns = [ 'Street', 'Price', 'City', 'Zipcode', 'State', 'First', 'Last',    'AgentEmail', 'AgentPhoneNumber', 'DaysOnZillow', 'hdpUrl'
        ]
        df['Price'] = df['Price'].astype(float).astype("Int32").apply(\
                                lambda x: "${:,.0f}".format(x) if isinstance(x, int) else x)
        df =df[df.AgentEmail.str.contains("@",na=False)]
        df =df.loc[df['DaysOnZillow'] < 365]
        from datetime import datetime
        today = date.today()
        print(df['State'][0])

        return df

# %%
df1.columns
# Out:
# Index(['zpid', 'homeStatus', 'bedrooms', 'bathrooms', 'price', 'yearBuilt',
#        'isRentalListingOffMarket', 'contingentListingType', 'pageViewCount',
#        'daysOnZillow', 'longitude', 'latitude', 'hdpUrl',
#        'desktopWebHdpImageLink', 'timeZone', 'brokerId', 'monthlyHoaFee',
#        'propertyTaxRate', 'lotSize', 'utcScrapeTime', 'streetAddress', 'city',
#        'state', 'zipcode', 'associationFee', 'buildingName',
#        'buyerAgencyCompensation', 'buyerAgencyCompensationType', 'basement',
#        'canRaiseHorses', 'coveredParkingCapacity', 'fireplaces',
#        'hasAssociation', 'hasFireplace', 'hasGarage', 'hasPrivatePool',
#        'hasWaterfrontView', 'parkingCapacity', 'pricePerSquareFoot', 'stories',
#        'hasRentControl', 'structureType', 'is_newHome', 'is_FSBO', 'is_FSBA',
#        'is_foreclosure', 'is_bankOwned', 'is_forAuction', 'is_comingSoon',
#        'is_pending', 'is_openHouse', 'listingAgreement', 'agentEmail',
#        'agentName', 'agentPhoneNumber', 'brokerName', 'brokerPhoneNumber',
#        'First', 'Last', 'averageSchoolRating', 'priceHistory'],
#       dtype='object')

# %%
df = create_excel(df1)
df = df.reset_index(drop=True)
df
# Out:
# NY
#                     Street    Price             City Zipcode State     First  \
# 0          L5.4 River Road  $10,000      Schenectady   12309    NY    Ursula
# 1         Ohalloran Circle  $10,000  Pleasant valley   12569    NY     Karen
# 2         6451 Westwood Dr  $10,000         Lockport   14094    NY    Carmen
# 3     2177 Clute Rd #202-A  $10,000         Cortland   13045    NY      John
# 4             24 Morton St  $10,000        Rochester   14609    NY    Joseph
# 5        L40 Perry Hill Rd  $10,000           Oswego   13126    NY     Allen
# 6                Dewey Ave  $10,000    North Collins   14111    NY   Melissa
# 7               Paine Road  $10,000           Holmes   12531    NY    Roslyn
# 8      LOT-17A W Thomas St  $10,000             Rome   13440    NY      Ryan
# 9            0 Stanton Ter   $9,999     Poughkeepsie   12603    NY      Omar
# 10         Stanton Terrace   $9,999     Poughkeepsie   12603    NY      Omar
# 11  Vl Monroe Avenue Evans   $9,999           Angola   14006    NY    Brandy
# 12               0 Gray St   $9,990        Dansville   14437    NY   Melissa
# 13       950 Humboldt Pkwy   $9,975          Buffalo   14211    NY  Kimberly
# 14        1156 Whitney Ave   $9,900    Niagara Falls   14301    NY      Todd
# 15        99 Forest Street   $9,900     Gloversville   12078    NY    Kayoko
#
#          Last                          AgentEmail AgentPhoneNumber  \
# 0      Mangir              ursulamangir@gmail.com     518-779-0462
# 1       Zayas            karen.zayasc21@gmail.com     845-764-1878
# 2    Laurendi               laurendi@laurendi.com     716-622-7660
# 3   Aspinwall             john@hagerealestate.com     607-745-8748
# 4     Simeone        jsimeonerealestate@gmail.com     585-888-4002
# 5     Olmsted            canaanrealtyny@gmail.com     315-682-4500
# 6     Weidner  Melissa.Weidner@huntrealestate.com     716-982-3084
# 7     Ralston             roslynralston@gmail.com     845-489-0382
# 8       Amuso                 ryanamuso@gmail.com     315-383-7733
# 9      Harper         myagentomarharper@gmail.com     845-857-0826
# 10     Harper         myagentomarharper@gmail.com     845-857-0826
# 11      Hardy                  hardy17b@gmail.com     716-574-8998
# 12      Bauco                      mabauco@kw.com     607-215-6569
# 13    Santana        kim@buffalovedevelopment.com     716-578-6465
# 14  Vanderlip             ToddVanderlip@gmail.com     716-563-2166
# 15    Lomanto           klomantorealtor@gmail.com             None
#
#     DaysOnZillow                                             hdpUrl
# 0            245  /homedetails/L54-River-Rd-Schenectady-NY-12309...
# 1            116  /homedetails/Ohalloran-Cir-Pleasant-Valley-NY-...
# 2             61  /homedetails/6451-Westwood-Dr-Lockport-NY-1409...
# 3             38  /homedetails/2177-Clute-Rd-202-A-Cortland-NY-1...
# 4             54  /homedetails/24-Morton-St-Rochester-NY-14609/1...
# 5              4  /homedetails/L40-Perry-Hill-Rd-Oswego-NY-13126...
# 6            108  /homedetails/Dewey-Ave-North-Collins-NY-14111/...
# 7             31  /homedetails/Paine-Rd-Holmes-NY-12531/15080775...
# 8             61  /homedetails/LOT-17A-W-Thomas-St-Rome-NY-13440...
# 9            120  /homedetails/0-Stanton-Ter-Poughkeepsie-NY-126...
# 10           120  /homedetails/Stanton-Ter-Poughkeepsie-NY-12603...
# 11            94  /homedetails/Vl-Monroe-Avenue-Evans-Angola-NY-...
# 12            47  /homedetails/0-Gray-St-Dansville-NY-14437/2069...
# 13           127  /homedetails/950-Humboldt-Pkwy-Buffalo-NY-1421...
# 14           310  /homedetails/1156-Whitney-Ave-Niagara-Falls-NY...
# 15           256  /homedetails/99-Forest-St-Gloversville-NY-1207...

# %%
r = BeautifulSoup(storage[0]['content'], 'html.parser')

# %%
r = sendRequest(link)

# %%
data1 = pprint(data.json())
# Out:
# {'results': [{'_request': {'cookies': [],
#                            'headers': {'Accept': 'text/html,application/xhtml+xml,image/jxr,*/*',
#                                        'Accept-Encoding': 'gzip,deflate',
#                                        'Accept-Language': 'en-US,en;q=0.7',
#                                        'Connection': 'Keep-Alive',
#                                        'User-Agent': 'Mozilla/5.0 (Windows NT '
#                                                      '10.0; Win64; x64) '
#                                                      'AppleWebKit/537.36 '
#                                                      '(KHTML like Gecko) '
#                                                      'Chrome/83.0.4103.116 '
#                                                      'Safari/537.36 '
#                                                      'Edg/83.0.478.64'}},
#               '_response': {'cookies': [{'comment': '',
#                                          'domain': '',
#                                          'expires': 'Fri, 16 Dec 2022 07:16:05 '
#                                                     'GMT',
#                                          'httponly': '',
#                                          'key': 'AWSALB',
#                                          'max-age': '',
#                                          'path': '/',
#                                          'samesite': '',
#                                          'secure': '',
#                                          'value': '8++ua9oudp3x75KZAjtAqeC1IaWLBZrETIriXmPkOSMgTQ7Rci/TgrCpBjU/h0CGo7HDPNXj7oYAwffPeNfPx8f+syo7QxNVf8PzmW/J054jGOUnS/l3kg+pEioW',
#                                          'version': ''},
#                                         {'comment': '',
#                                          'domain': '',
#                                          'expires': 'Fri, 16 Dec 2022 07:16:05 '
#                                                     'GMT',
#                                          'httponly': '',
#                                          'key': 'AWSALBCORS',
#                                          'max-age': '',
#                                          'path': '/',
#                                          'samesite': 'None',
#                                          'secure': True,
#                                          'value': '8++ua9oudp3x75KZAjtAqeC1IaWLBZrETIriXmPkOSMgTQ7Rci/TgrCpBjU/h0CGo7HDPNXj7oYAwffPeNfPx8f+syo7QxNVf8PzmW/J054jGOUnS/l3kg+pEioW',
#                                          'version': ''},
#                                         {'comment': '',
#                                          'domain': '',
#                                          'expires': '',
#                                          'httponly': True,
#                                          'key': 'JSESSIONID',
#                                          'max-age': '',
#                                          'path': '/',
#                                          'samesite': '',
#                                          'secure': True,
#                                          'value': '0F2F26FE61220184D629419AAF80AC09',
#                                          'version': ''},
#                                         {'comment': '',
#                                          'domain': '.zillow.com',
#                                          'expires': 'Wed, 08-Dec-2032 19:16:05 '
#                                                     'GMT',
#                                          'httponly': '',
#                                          'key': 'search',
#                                          'max-age': '',
#                                          'path': '/',
#                                          'samesite': '',
#                                          'secure': '',
#                                          'value': '6|1673162165016%7Cregion%3Dnj%26rect%3D41.357423%252C-73.88506%252C38.788657%252C-75.563586%26p%3D2%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%09%0940%09%09%09%09%09%09',
#                                          'version': ''},
#                                         {'comment': '',
#                                          'domain': '.zillow.com',
#                                          'expires': 'Wed, 8 Dec 2032 19:16:05 '
#                                                     'GMT',
#                                          'httponly': '',
#                                          'key': 'zguid',
#                                          'max-age': '315576000',
#                                          'path': '/',
#                                          'samesite': '',
#                                          'secure': '',
#                                          'value': '24|%24b798348d-4651-44e0-9675-447d3f0851a1',
#                                          'version': ''},
#                                         {'comment': '',
#                                          'domain': '.zillow.com',
#                                          'expires': '',
#                                          'httponly': True,
#                                          'key': 'zgsession',
#                                          'max-age': '',
#                                          'path': '/',
#                                          'samesite': '',
#                                          'secure': '',
#                                          'value': '1|1c874320-8046-4fb5-b1e1-2fc2aa68aaf5',
#                                          'version': ''}],
#                             'headers': {'alt-svc': 'h3=":443"; ma=86400',
#                                         'cache-control': 'no-cache',
#                                         'content-encoding': 'gzip',
#                                         'content-security-policy': 'frame-ancestors '
#                                                                    'zillow.highspot.com '
#                                                                    'view.highspot.com;',
#                                         'content-type': 'text/html;charset=UTF-8',
#                                         'date': 'Fri, 09 Dec 2022 07:16:05 GMT',
#                                         'expires': 'Thu, 01 Jan 1970 00:00:00 '
#                                                    'GMT',
#                                         'server': 'Apache-Coyote/1.1',
#                                         'vary': 'Accept-Encoding',
#                                         'via': '1.1 zgs, 1.1 '
#                                                '6fc1853aec8424fa9c4a2f1e81f20780.cloudfront.net '
#                                                '(CloudFront)',
#                                         'x-amz-cf-id': 'j6MgLeAhlLztQodfw7Rgxqpl3y1k6D10G6wtjtT7pODvzTUiIJCWLw==',
#                                         'x-amz-cf-pop': 'SOF50-C1',
#                                         'x-cache': 'Miss from cloudfront',
#                                         'x-frame-options': 'deny',
#                                         'x-internal-host': '029',
#                                         'z-using-act': '2'}},
#               'content': '<!DOCTYPE html><html itemscope="" '
#                          'itemtype="http://schema.org/Organization" '
#                          'class="no-js zsg-theme-modernized null" lang="en" '
#                          'xmlns="http://www.w3.org/1999/xhtml" '
#                          'xmlns:og="http://ogp.me/ns#" '
#                          'xmlns:fb="http://www.facebook.com/2008/fbml" '
#                          'xmlns:product="http://ogp.me/ns/product#" >\n'
#                          '<head>\n'
#                          '<title>NJ Real Estate - New Jersey Homes For Sale | '
#                          'Zillow</title><meta name="description" '
#                          'content="Zillow has 14360 homes for sale in New '
#                          'Jersey. View listing photos, review sales history, '
#                          'and use our detailed real estate filters to find the '
#                          'perfect place."></meta><meta name="author" '
#                          'content="Zillow, Inc."/><meta name="Copyright" '
#                          'content="Copyright (c) 2006-2022 Zillow, '
#                          'Inc."></meta><script>\n'
#                          "        if (typeof Object.assign === 'function') {\n"
#                          '            window.appInfo = Object.assign(\n'
#                          "                typeof window.appInfo === 'object' ? "
#                          'window.appInfo : {},\n'
#                          '                '
#                          '{"@zillow/page-frame-content":"2f789f5d"}\n'
#                          '            );\n'
#                          '        }\n'
#                          '    </script><script>\n'
#                          '        window.CLIENT_PROFILER_CONFIG = '
#                          'window.CLIENT_PROFILER_CONFIG || {\n'
#                          '            staticDimensions: {\n'
#                          '                ABDecisionToken: '
#                          '"Blhmut_1670570165",\n'
#                          '            },\n'
#                          '        };\n'
#                          '    '
#                          "</script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n"
#                          '        '
#                          '(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new '
#                          'Date();a=s.createElement(o),\n'
#                          '        '
#                          'm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n'
#                          '        '
#                          "})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');</script><script>window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new "
#                          'Date;\n'
#                          '    ga("create","UA-21174015-56", "auto", '
#                          '{allowLinker:true});\n'
#                          "    ga('set','dimension1', "
#                          "'b798348d465144e09675447d3f0851a1');\n"
#                          "    ga('set','dimension191', '');\n"
#                          '    /* Queue for Global UA Object */\n'
#                          '    '
#                          '(function(w,n){w[n]=w[n]||function(){(w[n].q=w[n].q||[]).push(arguments)}})(window, '
#                          "'ua');\n"
#                          "    ua('set','dimension1', "
#                          "'b798348d465144e09675447d3f0851a1');\n"
#                          "    ua('set','dimension191', '');\n"
#                          "    ua('set', "
#                          '{"dimension176":"AB_DASHBOARD_AA_TEST.CONTROL","dimension64":"ADAT_APS_EMPTY_CLIENT_INFO.CONTROL_DASH","dimension62":"AIPERS_COLLECTIONS_GEOLOCATION.CONTROL","dimension177":"AIPERS_COLLECTIONS_UPDATES_TAB.APP_D","dimension186":"AIPERS_HIDE_HOMES.CONTROL","dimension58":"ANDROID_NATIVE_STANDARD_TOUR_FORM_SLICE_B_FOLLOWUP.CONTROL","dimension37":"ANDROID_PHOTO_CAROUSEL.CONTROL_PHOTO_CAROUSEL","dimension185":"ARCS_INSTANT_BOOK.ON","dimension49":"AR_MY_AGENT_POST_SUBMIT_MIGRATION_MOBILE.CONTROL","dimension44":"AR_MY_AGENT_RECONNECTIONS_LOGGED_OUT_OPAQUE.ON","dimension56":"AuthN_VerifyMailReg.CONTROL","dimension165":"CW_CONTACT_FORM_SUPPORT_MANUFACTURED.CONTROL","dimension168":"CW_FINANCE_WITH_INLINE_WEB.THREE_VARIANT","dimension169":"CW_HIGH_INTENT_PHONE_ANDROID.CONTROL","dimension60":"CW_HIGH_INTENT_PHONE_DESKTOP.LOW_HDP_NATIONAL","dimension182":"CW_HIGH_INTENT_PHONE_IOS.CONTROL","dimension166":"CW_HIGH_INTENT_PHONE_MWEB.CONTACT_FORM_LOCAL","dimension59":"DXP_CONST_PROPCARD_MAPVIEW.CONTROL","dimension48":"DXP_PHOTO_CAROUSEL.CONTROL","dimension63":"DXP_SEE_MORE_RECS.SCROLL_ON","dimension175":"HDP_DEEP_DIVE_REORDER.VARIANT_A","dimension174":"HDP_DEEP_DIVE_REORDER_APP.CONTROL","dimension172":"HDP_INSIGHTS_VERSION.CONTROL","dimension187":"HDP_MEDIASOLUTIONS_ADS_WEB_PROG.CONTROL","dimension38":"IOS_MONTHLY_COST_FILTER_MVP.ON","dimension184":"IOS_NATIVE_SHARE_SHEET.ON","dimension57":"IOS_NATIVE_TOUR_FORM_TREATMENT.CONTROL","dimension45":"IOS_OMHDP_NATIVE_HOMEVALUE.CONTROL_OFF","dimension181":"IOS_PHOTO_CAROUSEL.CONTROL_OFF","dimension164":"IOS_SH_TOUR_CTA.CONTROL","dimension61":"LEGO_RENTALS_COMPARISON_TOOL.CONTROL","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension183":"RE_HDP_REDIRECT.TEST","dimension40":"RE_NON_VARIANT_HDP_DEFERRED_HYDRATION.TEST","dimension41":"RE_contacted_hdp_bdp.AA_VARIANT","dimension39":"RMX_AGENT_PROMINENCE.CONTROL","dimension179":"SP_OFF_MARKET_PAGE.CONTROL","dimension171":"SXP_MULTIREGION_SEARCH.CONTROL","dimension47":"SXP_Search_Refinement_Filters.FILTERS_ON","dimension46":"SXP_VISUAL_AUDIT_2021.CONTROL","dimension173":"VL_LAYOUT.CONTROL","dimension36":"VL_RENTAL_DATA_API.CONTROL","dimension167":"WEB_HIDDEN_HOMES_2022.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.Blhmut_1670570165","dimension178":"ZHL_PREQUAL_CTAS.CONTROL"}); '
#                          "ga('set', "
#                          '{"dimension176":"AB_DASHBOARD_AA_TEST.CONTROL","dimension64":"ADAT_APS_EMPTY_CLIENT_INFO.CONTROL_DASH","dimension62":"AIPERS_COLLECTIONS_GEOLOCATION.CONTROL","dimension177":"AIPERS_COLLECTIONS_UPDATES_TAB.APP_D","dimension186":"AIPERS_HIDE_HOMES.CONTROL","dimension58":"ANDROID_NATIVE_STANDARD_TOUR_FORM_SLICE_B_FOLLOWUP.CONTROL","dimension37":"ANDROID_PHOTO_CAROUSEL.CONTROL_PHOTO_CAROUSEL","dimension185":"ARCS_INSTANT_BOOK.ON","dimension49":"AR_MY_AGENT_POST_SUBMIT_MIGRATION_MOBILE.CONTROL","dimension44":"AR_MY_AGENT_RECONNECTIONS_LOGGED_OUT_OPAQUE.ON","dimension56":"AuthN_VerifyMailReg.CONTROL","dimension165":"CW_CONTACT_FORM_SUPPORT_MANUFACTURED.CONTROL","dimension168":"CW_FINANCE_WITH_INLINE_WEB.THREE_VARIANT","dimension169":"CW_HIGH_INTENT_PHONE_ANDROID.CONTROL","dimension60":"CW_HIGH_INTENT_PHONE_DESKTOP.LOW_HDP_NATIONAL","dimension182":"CW_HIGH_INTENT_PHONE_IOS.CONTROL","dimension166":"CW_HIGH_INTENT_PHONE_MWEB.CONTACT_FORM_LOCAL","dimension59":"DXP_CONST_PROPCARD_MAPVIEW.CONTROL","dimension48":"DXP_PHOTO_CAROUSEL.CONTROL","dimension63":"DXP_SEE_MORE_RECS.SCROLL_ON","dimension175":"HDP_DEEP_DIVE_REORDER.VARIANT_A","dimension174":"HDP_DEEP_DIVE_REORDER_APP.CONTROL","dimension172":"HDP_INSIGHTS_VERSION.CONTROL","dimension187":"HDP_MEDIASOLUTIONS_ADS_WEB_PROG.CONTROL","dimension38":"IOS_MONTHLY_COST_FILTER_MVP.ON","dimension184":"IOS_NATIVE_SHARE_SHEET.ON","dimension57":"IOS_NATIVE_TOUR_FORM_TREATMENT.CONTROL","dimension45":"IOS_OMHDP_NATIVE_HOMEVALUE.CONTROL_OFF","dimension181":"IOS_PHOTO_CAROUSEL.CONTROL_OFF","dimension164":"IOS_SH_TOUR_CTA.CONTROL","dimension61":"LEGO_RENTALS_COMPARISON_TOOL.CONTROL","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension183":"RE_HDP_REDIRECT.TEST","dimension40":"RE_NON_VARIANT_HDP_DEFERRED_HYDRATION.TEST","dimension41":"RE_contacted_hdp_bdp.AA_VARIANT","dimension39":"RMX_AGENT_PROMINENCE.CONTROL","dimension179":"SP_OFF_MARKET_PAGE.CONTROL","dimension171":"SXP_MULTIREGION_SEARCH.CONTROL","dimension47":"SXP_Search_Refinement_Filters.FILTERS_ON","dimension46":"SXP_VISUAL_AUDIT_2021.CONTROL","dimension173":"VL_LAYOUT.CONTROL","dimension36":"VL_RENTAL_DATA_API.CONTROL","dimension167":"WEB_HIDDEN_HOMES_2022.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.Blhmut_1670570165","dimension178":"ZHL_PREQUAL_CTAS.CONTROL"});\n'
#                          '    </script><script>\n'
#                          '        !function () {\n'
#                          '            // Getting OptanonConsent cookie from '
#                          'document.cookie\n'
#                          '            var n = !1,\n'
#                          '                op = document.cookie && '
#                          'document.cookie.split("; ").filter(function(n){ '
#                          'return n.indexOf("OptanonConsent=") === 0; });\n'
#                          '            try {\n'
#                          '                var o = op && op.length > 0 && '
#                          'op[0];\n'
#                          '                if (void 0 !== o && null != o) {\n'
#                          '                    // Parse and read OptanonConsent '
#                          'cookie, look for groups.\n'
#                          '                    var i = '
#                          'decodeURIComponent(o).split("&").filter(function(n) '
#                          '{ return n.indexOf("groups=") !== -1; });\n'
#                          '                    if(i.length > 0) {\n'
#                          '                        // Groups will look like '
#                          '1:0,3:0,4:0. We want to check if the 3:0 exists, '
#                          'which is the code for functional blocking\n'
#                          '                        var m = '
#                          'i[0].substring(i[0].indexOf("=")).split(",");\n'
#                          '                        for (var k = 0; k < '
#                          'm.length; k++) {\n'
#                          '                            m[k].split(":").length > '
#                          '1 && "3" === m[k].split(":")[0] && "0" === '
#                          'm[k].split(":")[1] && (n = !0)\n'
#                          '                        }\n'
#                          '                    }\n'
#                          '                }\n'
#                          '            }\n'
#                          '            catch(e) {};\n'
#                          "            window['ga-disable-' + 'UA-21174015-56'] "
#                          '= n;\n'
#                          "            window['disable-analytics'] = n;\n"
#                          '        }();\n'
#                          '            \n'
#                          '        (function(w,d,ns,cdn,opt,ml,fa,my,fst){\n'
#                          '        '
#                          "w['ZillowAnalyticsObject']=ns;w[ns]=w[ns]||[];\n"
#                          '        if(w[ns].initialize||w[ns].invoked)return;\n'
#                          '        w[ns].invoked=1;w[ns]._loadOptions=opt;\n'
#                          '        '
#                          "ml=['identify','track','page','off','on','use','unuse','setdim','setprop','event','send','dwell','dwellEnd'];\n"
#                          '        fa=function(m){return '
#                          'function(){w[ns].push([].concat(m,[].slice.call(arguments)));return '
#                          'w[ns]}};\n'
#                          '        ml.forEach(function(mn){w[ns][mn]=fa(mn)});\n'
#                          '        var x=!(window && '
#                          "window['disable-analytics']);\n"
#                          '        '
#                          "if(x){my=d.createElement('script');fst=d.getElementsByTagName('script')[0];\n"
#                          '        '
#                          'my.defer=!0;my.src=cdn;if(fst)fst.parentNode.insertBefore(my,fst);}\n'
#                          '        return w[ns];\n'
#                          "        })(window,document,'zanalytics', "
#                          "'https://e.zg-api.com/a/z/js/v1/analytics.js?v=bcf290c', "
#                          "{'zillow': {\n"
#                          "            apiKey: 'z_prod',\n"
#                          "            apiHost: 'e.zg-api.com:443',\n"
#                          '            secure: true,\n'
#                          '            anonymousId: '
#                          "'b798348d-4651-44e0-9675-447d3f0851a1',\n"
#                          '        '
#                          '}});</script><script>window.__USER_SESSION_INITIAL_STATE__ '
#                          '= { user: { loggedIn: false } };</script><script>\n'
#                          '        var customDimension1 = '
#                          "'b798348d465144e09675447d3f0851a1';\n"
#                          "        ua('set', 'dimension1', customDimension1);\n"
#                          "        ga('set', 'dimension1', "
#                          'customDimension1);</script><script>\n'
#                          '        var w = window.innerWidth\n'
#                          '            || (document && document.documentElement '
#                          '&& document.documentElement.clientWidth)\n'
#                          '            || (document && document.body && '
#                          'document.body.clientWidth);\n'
#                          '\n'
#                          '        var h = window.innerHeight\n'
#                          '            || (document && document.documentElement '
#                          '&& document.documentElement.clientHeight)\n'
#                          '            || (document && document.body && '
#                          'document.body.clientHeight);\n'
#                          '\n'
#                          '        ua(\'set\', \'dimension20\', w + "x" + h);\n'
#                          "        ua('set','dimension68', "
#                          'window.location.href);\n'
#                          "        ua('set', 'dimension69', "
#                          'document.referrer);\n'
#                          "        ua('set', 'dimension192', '1670570165307');\n"
#                          '        ga(\'set\', \'dimension20\', w + "x" + h);\n'
#                          "        ga('set','dimension68', "
#                          'window.location.href);\n'
#                          "        ga('set', 'dimension69', "
#                          'document.referrer);\n'
#                          "        ga('set', 'dimension192', '1670570165307');\n"
#                          '\n'
#                          '        '
#                          "document.addEventListener('DOMContentLoaded', "
#                          'function ProfileDOMContentLoadedEvent (e) {\n'
#                          '            // wait two seconds to make sure this '
#                          'performance metric has been recorded\n'
#                          '            setTimeout(function () {\n'
#                          '                if (performance && '
#                          'performance.timing) {\n'
#                          '                    var domContentLoadedTime = '
#                          '((performance.timing.domContentLoadedEventStart - '
#                          'performance.timing.navigationStart)/1000).toFixed(2);\n'
#                          "                    ua('set', 'dimension72', "
#                          'domContentLoadedTime);\n'
#                          "                    ga('set', 'dimension72', "
#                          'domContentLoadedTime);\n'
#                          '                }\n'
#                          '            }, 2000);\n'
#                          '            '
#                          "document.removeEventListener('DOMContentLoaded', "
#                          'ProfileDOMContentLoadedEvent);\n'
#                          '        });\n'
#                          '\n'
#                          "        window.addEventListener('load', function "
#                          'ProfileLoadEvent (e) {\n'
#                          '            // wait two seconds to make sure this '
#                          'performance metric has been recorded\n'
#                          '            setTimeout(function () {\n'
#                          '                if (performance && '
#                          'performance.timing) {\n'
#                          '                    var loadEventTime = '
#                          '((performance.timing.loadEventEnd - '
#                          'performance.timing.navigationStart)/1000).toFixed(2);\n'
#                          "                    ua('set', 'dimension73', "
#                          'loadEventTime);\n'
#                          "                    ga('set', 'dimension73', "
#                          'loadEventTime);\n'
#                          '                }\n'
#                          '            }, 2000);\n'
#                          "            window.removeEventListener('load', "
#                          'ProfileLoadEvent);\n'
#                          '        });\n'
#                          '    </script><script '
#                          'type="text/javascript">ua(\'set\', '
#                          '{"dimension176":"AB_DASHBOARD_AA_TEST.CONTROL","dimension64":"ADAT_APS_EMPTY_CLIENT_INFO.CONTROL_DASH","dimension62":"AIPERS_COLLECTIONS_GEOLOCATION.CONTROL","dimension177":"AIPERS_COLLECTIONS_UPDATES_TAB.APP_D","dimension186":"AIPERS_HIDE_HOMES.CONTROL","dimension58":"ANDROID_NATIVE_STANDARD_TOUR_FORM_SLICE_B_FOLLOWUP.CONTROL","dimension37":"ANDROID_PHOTO_CAROUSEL.CONTROL_PHOTO_CAROUSEL","dimension185":"ARCS_INSTANT_BOOK.ON","dimension49":"AR_MY_AGENT_POST_SUBMIT_MIGRATION_MOBILE.CONTROL","dimension44":"AR_MY_AGENT_RECONNECTIONS_LOGGED_OUT_OPAQUE.ON","dimension56":"AuthN_VerifyMailReg.CONTROL","dimension165":"CW_CONTACT_FORM_SUPPORT_MANUFACTURED.CONTROL","dimension168":"CW_FINANCE_WITH_INLINE_WEB.THREE_VARIANT","dimension169":"CW_HIGH_INTENT_PHONE_ANDROID.CONTROL","dimension60":"CW_HIGH_INTENT_PHONE_DESKTOP.LOW_HDP_NATIONAL","dimension182":"CW_HIGH_INTENT_PHONE_IOS.CONTROL","dimension166":"CW_HIGH_INTENT_PHONE_MWEB.CONTACT_FORM_LOCAL","dimension59":"DXP_CONST_PROPCARD_MAPVIEW.CONTROL","dimension48":"DXP_PHOTO_CAROUSEL.CONTROL","dimension63":"DXP_SEE_MORE_RECS.SCROLL_ON","dimension175":"HDP_DEEP_DIVE_REORDER.VARIANT_A","dimension174":"HDP_DEEP_DIVE_REORDER_APP.CONTROL","dimension172":"HDP_INSIGHTS_VERSION.CONTROL","dimension187":"HDP_MEDIASOLUTIONS_ADS_WEB_PROG.CONTROL","dimension38":"IOS_MONTHLY_COST_FILTER_MVP.ON","dimension184":"IOS_NATIVE_SHARE_SHEET.ON","dimension57":"IOS_NATIVE_TOUR_FORM_TREATMENT.CONTROL","dimension45":"IOS_OMHDP_NATIVE_HOMEVALUE.CONTROL_OFF","dimension181":"IOS_PHOTO_CAROUSEL.CONTROL_OFF","dimension164":"IOS_SH_TOUR_CTA.CONTROL","dimension61":"LEGO_RENTALS_COMPARISON_TOOL.CONTROL","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension183":"RE_HDP_REDIRECT.TEST","dimension40":"RE_NON_VARIANT_HDP_DEFERRED_HYDRATION.TEST","dimension41":"RE_contacted_hdp_bdp.AA_VARIANT","dimension39":"RMX_AGENT_PROMINENCE.CONTROL","dimension179":"SP_OFF_MARKET_PAGE.CONTROL","dimension171":"SXP_MULTIREGION_SEARCH.CONTROL","dimension47":"SXP_Search_Refinement_Filters.FILTERS_ON","dimension46":"SXP_VISUAL_AUDIT_2021.CONTROL","dimension173":"VL_LAYOUT.CONTROL","dimension36":"VL_RENTAL_DATA_API.CONTROL","dimension167":"WEB_HIDDEN_HOMES_2022.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.Blhmut_1670570165","dimension178":"ZHL_PREQUAL_CTAS.CONTROL"}); '
#                          "ga('set', "
#                          '{"dimension176":"AB_DASHBOARD_AA_TEST.CONTROL","dimension64":"ADAT_APS_EMPTY_CLIENT_INFO.CONTROL_DASH","dimension62":"AIPERS_COLLECTIONS_GEOLOCATION.CONTROL","dimension177":"AIPERS_COLLECTIONS_UPDATES_TAB.APP_D","dimension186":"AIPERS_HIDE_HOMES.CONTROL","dimension58":"ANDROID_NATIVE_STANDARD_TOUR_FORM_SLICE_B_FOLLOWUP.CONTROL","dimension37":"ANDROID_PHOTO_CAROUSEL.CONTROL_PHOTO_CAROUSEL","dimension185":"ARCS_INSTANT_BOOK.ON","dimension49":"AR_MY_AGENT_POST_SUBMIT_MIGRATION_MOBILE.CONTROL","dimension44":"AR_MY_AGENT_RECONNECTIONS_LOGGED_OUT_OPAQUE.ON","dimension56":"AuthN_VerifyMailReg.CONTROL","dimension165":"CW_CONTACT_FORM_SUPPORT_MANUFACTURED.CONTROL","dimension168":"CW_FINANCE_WITH_INLINE_WEB.THREE_VARIANT","dimension169":"CW_HIGH_INTENT_PHONE_ANDROID.CONTROL","dimension60":"CW_HIGH_INTENT_PHONE_DESKTOP.LOW_HDP_NATIONAL","dimension182":"CW_HIGH_INTENT_PHONE_IOS.CONTROL","dimension166":"CW_HIGH_INTENT_PHONE_MWEB.CONTACT_FORM_LOCAL","dimension59":"DXP_CONST_PROPCARD_MAPVIEW.CONTROL","dimension48":"DXP_PHOTO_CAROUSEL.CONTROL","dimension63":"DXP_SEE_MORE_RECS.SCROLL_ON","dimension175":"HDP_DEEP_DIVE_REORDER.VARIANT_A","dimension174":"HDP_DEEP_DIVE_REORDER_APP.CONTROL","dimension172":"HDP_INSIGHTS_VERSION.CONTROL","dimension187":"HDP_MEDIASOLUTIONS_ADS_WEB_PROG.CONTROL","dimension38":"IOS_MONTHLY_COST_FILTER_MVP.ON","dimension184":"IOS_NATIVE_SHARE_SHEET.ON","dimension57":"IOS_NATIVE_TOUR_FORM_TREATMENT.CONTROL","dimension45":"IOS_OMHDP_NATIVE_HOMEVALUE.CONTROL_OFF","dimension181":"IOS_PHOTO_CAROUSEL.CONTROL_OFF","dimension164":"IOS_SH_TOUR_CTA.CONTROL","dimension61":"LEGO_RENTALS_COMPARISON_TOOL.CONTROL","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension183":"RE_HDP_REDIRECT.TEST","dimension40":"RE_NON_VARIANT_HDP_DEFERRED_HYDRATION.TEST","dimension41":"RE_contacted_hdp_bdp.AA_VARIANT","dimension39":"RMX_AGENT_PROMINENCE.CONTROL","dimension179":"SP_OFF_MARKET_PAGE.CONTROL","dimension171":"SXP_MULTIREGION_SEARCH.CONTROL","dimension47":"SXP_Search_Refinement_Filters.FILTERS_ON","dimension46":"SXP_VISUAL_AUDIT_2021.CONTROL","dimension173":"VL_LAYOUT.CONTROL","dimension36":"VL_RENTAL_DATA_API.CONTROL","dimension167":"WEB_HIDDEN_HOMES_2022.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.Blhmut_1670570165","dimension178":"ZHL_PREQUAL_CTAS.CONTROL"});</script><script>window.UI_INIT_AT '
#                          '= Date.now()</script><script>(function(n,a,e){var '
#                          'r="v2",i="fontsVersion",t="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700&display=swap",c="//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-",o="",s="",l="",f="",u={};var '
#                          'S=function(){var '
#                          'e="__zstorage__";try{localStorage.setItem(e,e);localStorage.removeItem(e);return '
#                          'true}catch(e){return false}}();var '
#                          'p=function(){try{return '
#                          'a.createElement("link").relList.supports("prefetch")}catch(e){return '
#                          'false}}();function d(e){var '
#                          't=n.requestIdleCallback;t&&t(e)||setTimeout(e,1)}function '
#                          'v(e){var '
#                          't=a.createElement("style");t.type="text/css";t.appendChild(a.createTextNode(e));a.head.appendChild(t)}function '
#                          'y(e,t){var '
#                          'n=a.createElement("link");n.rel=t;n.href=e;a.head.appendChild(n)}u.setOpenSansFallbackStyle=function(e){f=e};u.insertOpenSansFallbackStyle=function(){f&&v(f)};u.insertOpenSansStyle=function(){y(t,"stylesheet")};u.setIvarFallbackStyle=function(e){l=e};u.insertIvarFallbackStyle=function(){l&&v(l)};u.setIvarStyle=function(e){o=e};u.insertIvarStyle=function(){o&&v(o)};u.setIvarSubsetStyle=function(e){s=e};u.insertIvarSubsetStyle=function(){s&&v(s)};u.prefetchIvarResources=function(){if(p){y(c+"core.woff2","prefetch");y(c+"extended.woff2","prefetch")}};u.prefetchOpenSansResources=function(){if(p){y(t,"prefetch")}};u.initFirstLoad=function(e){e=e||{};localStorage[i]=r;u.insertIvarSubsetStyle();var '
#                          't=e.prefetcher||function(e){n.addEventListener("load",function(){d(e)})};t(function(){u.prefetchIvarResources()})};u.initSecondLoad=function(){u.insertIvarStyle()};u.init=function(e){u.insertOpenSansFallbackStyle();u.insertIvarFallbackStyle();u.insertOpenSansStyle();if(!S||localStorage[i]===r){u.initSecondLoad()}else{u.initFirstLoad(e)}};n[e]=n[e]||u})(window,document,"ZillowFontLoader");\n'
#                          '    '
#                          "ZillowFontLoader.setOpenSansFallbackStyle('@font-face{size-adjust:105%;ascent-override:103%;font-family:Adjusted "
#                          'Arial;font-weight:400;src:local("Arial")}@font-face{size-adjust:99.5%;ascent-override:98%;font-family:Adjusted '
#                          'Arial;font-weight:700;src:local("Arial Bold")}\');\n'
#                          '    '
#                          "ZillowFontLoader.setIvarFallbackStyle('@font-face{size-adjust:100.5%;ascent-override:77%;font-family:Adjusted "
#                          'Times;font-weight:600;src:local("Times '
#                          'Bold")}@font-face{size-adjust:104%;ascent-override:88%;font-family:Adjusted '
#                          'Times New Roman;font-weight:600;src:local("Times New '
#                          'Roman Bold")}\');\n'
#                          '    '
#                          "ZillowFontLoader.setIvarStyle('@font-face{font-display:swap;font-family:Ivar "
#                          'Headline;font-style:normal;font-weight:600;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff2) '
#                          'format("woff2"),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff) '
#                          'format("woff");unicode-range:u+0000-001f,u+0080-200f,u+2020-faff,u+fb10-ffff}@font-face{font-display:swap;font-family:Ivar '
#                          'Headline;font-style:normal;font-weight:600;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff2) '
#                          'format("woff2"),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff) '
#                          'format("woff");unicode-range:u+0020-007f,u+201?,u+fb0?}\');\n'
#                          '    '
#                          "</script><script>ZillowFontLoader.setIvarSubsetStyle('@font-face{font-display:swap;font-family:Ivar "
#                          'Headline '
#                          'Subset;font-style:normal;font-weight:600;src:url("data:application/x-font-woff2;charset=utf-8;base64,...") '
#                          'format("woff2");unicode-range:u+0020,u+0041-005a,u+0061-007a}\');</script><script>ZillowFontLoader.init();</script><link '
#                          'rel="dns-prefetch" '
#                          'href="//fonts.googleapis.com"/><meta '
#                          'charSet="utf-8"/><meta name="format-detection" '
#                          'content="telephone=no"/><meta '
#                          'http-equiv="x-dns-prefetch-control" '
#                          'content="on"/><meta name="referrer" '
#                          'content="always"/><meta name="viewport" '
#                          'content="width=device-width, height=device-height, '
#                          'user-scalable=yes, initial-scale=1.0, '
#                          'minimum-scale=1.0"/><meta '
#                          'name="msapplication-TileColor" '
#                          'content="#3366b8"/><meta '
#                          'name="msapplication-TileImage" '
#                          'content="https://www.zillowstatic.com//static/images/logos/zillow-logo-win8-tile.png"/><meta '
#                          'name="msapplication-config" content="none"/><meta '
#                          'name="apple-mobile-web-app-capable" '
#                          'content="yes"/><meta '
#                          'name="apple-mobile-web-app-status-bar-style" '
#                          'content="black-translucent"/><link '
#                          'rel="apple-touch-icon" '
#                          'href="/apple-touch-icon.png"/><meta '
#                          'property="fb:app_id" '
#                          'content="172285552816089"/><meta '
#                          'name="google-translate-customization" '
#                          'content="691f1bfccade71b5-c065751219a379dd-g64cedb67f5ea020a-a"/><meta '
#                          'name="google-signin-clientid" '
#                          'content="238648973530.apps.googleusercontent.com"/><meta '
#                          'name="google-signin-scope" content="openid profile '
#                          'email"/><meta name="google-signin-cookiepolicy" '
#                          'content="single_host_origin"/><meta '
#                          'property="og:site_name" '
#                          'content="Zillow"/><script>(function() {\n'
#                          '            if (typeof '
#                          'ga===undefined||!Array.isArray(ga.q)){return}\n'
#                          '            var '
#                          'gaSetCalls=[].concat(ga.q).filter(function(args){return '
#                          "args && args[0]==='set'});\n"
#                          '            var dims = {};\n'
#                          '            gaSetCalls.forEach(function(cmdCall) {\n'
#                          '                var arg1=cmdCall[1], '
#                          'arg2=cmdCall[2];\n'
#                          "                if (typeof arg1==='string') {\n"
#                          '                    dims[arg1] = arg2;\n'
#                          "                } else if (typeof arg1==='object' && "
#                          'arg1!==null) {\n'
#                          '                    '
#                          'Object.getOwnPropertyNames(arg1).forEach(function(k) '
#                          '{dims[k] = arg1[k]});\n'
#                          '                }\n'
#                          '            });\n'
#                          "            if (typeof zanalytics!=='undefined' && "
#                          "typeof zanalytics.setdim==='function') "
#                          '{zanalytics.setdim(dims)}\n'
#                          '        })();</script><script>\n'
#                          '            if (window.ClientProfiler) {\n'
#                          '                window.ClientProfiler.appConfig = {\n'
#                          '                    staticBeaconData: {\n'
#                          '                        pageName: '
#                          "'Search:RealEstateSearch:List',\n"
#                          '                        hostId: '
#                          "'orb-del-pre-029.uni.zillow.local',\n"
#                          '                        requestId: '
#                          "'3_ba878PTy2Fz7K7DfucFQ'\n"
#                          '                    }\n'
#                          '                }\n'
#                          '            }\n'
#                          '        </script><link rel="preconnect" '
#                          'href="//photos.zillowstatic.com"/><link '
#                          'rel="preconnect" '
#                          'href="//fonts.googleapis.com"/><link '
#                          'rel="preconnect" href="//maps.googleapis.com"/><link '
#                          'rel="preconnect" href="//c.go-mpulse.net"/><link '
#                          'rel="preconnect" href="//s.zillowstatic.com"/><link '
#                          'rel="preconnect" href="//fonts.gstatic.com"/><link '
#                          'rel="preconnect" '
#                          'href="//www.google-analytics.com"/><link '
#                          'rel="preconnect" '
#                          'href="//sb.scorecardresearch.com"/><link '
#                          'rel="preconnect" href="//e.zg-api.com"/><link '
#                          'rel="preconnect" crossorigin="true" '
#                          'href="//pf.zillow.com"></link><link rel="preconnect" '
#                          'crossorigin="true" '
#                          'href="https://mortgageapi.zillow.com"></link><script '
#                          'type="application/javascript">\n'
#                          '        !function(e){var t={};function '
#                          '__webpack_require__(n){if(t[n])return '
#                          't[n].exports;var r=t[n]={i:n,l:!1,exports:{}};return '
#                          'e[n].call(r.exports,r,r.exports,__webpack_require__),r.l=!0,r.exports}__webpack_require__.m=e,__webpack_require__.c=t,__webpack_require__.d=function(e,t,n){__webpack_require__.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:n})},__webpack_require__.r=function(e){"undefined"!=typeof '
#                          'Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},__webpack_require__.t=function(e,t){if(1&t&&(e=__webpack_require__(e)),8&t)return '
#                          'e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return '
#                          'e;var '
#                          'n=Object.create(null);if(__webpack_require__.r(n),Object.defineProperty(n,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof '
#                          'e)for(var r in '
#                          'e)__webpack_require__.d(n,r,(function(t){return '
#                          'e[t]}).bind(null,r));return '
#                          'n},__webpack_require__.n=function(e){var '
#                          't=e&&e.__esModule?function getDefault(){return '
#                          'e.default}:function getModuleExports(){return '
#                          'e};return '
#                          '__webpack_require__.d(t,"a",t),t},__webpack_require__.o=function(e,t){return '
#                          'Object.prototype.hasOwnProperty.call(e,t)},__webpack_require__.p="",__webpack_require__(__webpack_require__.s=0)}({"/uRe":function(e,t,n){"use '
#                          'strict";n.r(t);var r=n("5cLd"),i=n.n(r);function '
#                          '_defineProperty(e,t,n){return t in '
#                          'e?Object.defineProperty(e,t,{value:n,enumerable:!0,configurable:!0,writable:!0}):e[t]=n,e}var '
#                          'u=function LifeCycleEventQueue(){var '
#                          'e=this;_defineProperty(this,"checkRefire",(function(){!e.pendingRefireAnimationFrame&&(e.pendingScriptCount>0||e.hasFired)&&(e.pendingRefireAnimationFrame=!0,window.setTimeout((function(){return '
#                          'e.loadAssets()}),0))})),_defineProperty(this,"addCss",(function(t){e.cssQueue.push(t),e.checkRefire()})),_defineProperty(this,"addScript",(function(t){e.scriptQueue.push(t),e.checkRefire()})),_defineProperty(this,"addCallback",(function(t){e.callbackQueue.push(t),e.checkRefire()})),_defineProperty(this,"loadAssets",(function(){e.testHookOverride?e.testHookOverride():(e.loadCss(),e.loadScripts(),e.pendingRefireAnimationFrame=!1)})),_defineProperty(this,"loadCss",(function(){var '
#                          't=document.getElementsByTagName("head")[0];if(t&&0!==e.cssQueue.length){var '
#                          "n=e.cssQueue.reduce((function(e,t){return e+'<link "
#                          'href="\'+t+\'" type="text/css" rel="stylesheet" '
#                          '/>\'}),"");t.insertAdjacentHTML("beforeend",n),e.cssQueue=[]}})),_defineProperty(this,"loadScripts",(function(){document.getElementsByTagName("head")[0]&&e.scriptQueue.length>0&&(e.pendingScriptCount+=e.scriptQueue.length,e.scriptQueue.forEach((function(t){Array.isArray(t)?e.loadScriptSequence(t):e.loadScript(t)})),e.scriptQueue=[]),e.pendingScriptCount++,e.onScriptLoad()})),_defineProperty(this,"loadScript",(function(t){var '
#                          'n=document.getElementsByTagName("head")[0],r=document.createElement("script");r.setAttribute("src",t),r.addEventListener("load",e.onScriptLoad),n.appendChild(r)})),_defineProperty(this,"loadScriptSequence",(function(t){if(1!==t.length){var '
#                          'n=[].concat(t),r=document.getElementsByTagName("head")[0],i=document.createElement("script"),u=n.shift();i.setAttribute("src",u),i.addEventListener("load",(function(){return '
#                          'e.loadScriptSequence(n)})),r.appendChild(i)}else '
#                          'e.loadScript(t[0])})),_defineProperty(this,"onScriptLoad",(function(){e.pendingScriptCount>0&&e.pendingScriptCount--,0===e.pendingScriptCount&&window.setTimeout((function(){return '
#                          'e.fireCallbacks()}),0)})),_defineProperty(this,"fireCallbacks",(function(){e.callbackQueue.forEach((function(e){return '
#                          'e()})),e.callbackQueue=[],e.hasFired=!0})),_defineProperty(this,"addLoadAssetsTestOverride",(function(t){e.testHookOverride=t})),_defineProperty(this,"clearLoadAssetsTestOverride",(function(){e.testHookOverride=null})),this.scriptQueue=[],this.cssQueue=[],this.callbackQueue=[],this.pendingScriptCount=0,this.loadingAssets=!1,this.hasFired=!1,this.testHookOverride=null,this.pendingRefireAnimationFrame=!1};function '
#                          'LifeCycleQueueEventManager_defineProperty(e,t,n){return '
#                          't in '
#                          'e?Object.defineProperty(e,t,{value:n,enumerable:!0,configurable:!0,writable:!0}):e[t]=n,e}var '
#                          'o=function buildEventQueueName(e){return '
#                          'i()(e)+"Queue"};"undefined"==typeof '
#                          'window||window.LifeCycleQueueEventManager||(window.LifeCycleQueueEventManager=function '
#                          'LifeCycleEventQueueManager(e){var t=this;void '
#                          '0===e&&(e=["load","priorityUIReady","criticalPathComplete","HDPPriorityUIReady"]),LifeCycleQueueEventManager_defineProperty(this,"addScriptToEvent",(function(e,n){e&&0!==e.length&&(t.eventNames.indexOf(n)<0&&t.handleEventNameError(n),t[o(n)].addScript(e))})),LifeCycleQueueEventManager_defineProperty(this,"addCssToEvent",(function(e,n){e&&0!==e.length&&(t.eventNames.indexOf(n)<0&&t.handleEventNameError(n),t[o(n)].addCss(e))})),LifeCycleQueueEventManager_defineProperty(this,"addCallbackToEvent",(function(e,n){e&&(t.eventNames.indexOf(n)<0&&t.handleEventNameError(n),t[o(n)].addCallback(e))})),LifeCycleQueueEventManager_defineProperty(this,"handleEventNameError",(function(e){throw '
#                          'new Error(e+" is not an acceptable event name. Try '
#                          'one of "+t.eventNames.join(" '
#                          '"))})),this.eventNames=e,this.eventNames.forEach((function(e){t[o(e)]=new '
#                          'u(e),t[function '
#                          'buildLoadAssetFunctionName(e){return"load"+i()(e)+"EventAssets"}(e)]=function(){return '
#                          't[o(e)].loadAssets()}}))})},0:function(e,t,n){n("HGSC"),e.exports=n("/uRe")},"5cLd":function(e,t,n){(function(t){var '
#                          'n=/[^\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\x7f]+/g,r=/[\\xc0-\\xd6\\xd8-\\xf6\\xf8-\\xff\\u0100-\\u017f]/g,i="\\\\xac\\\\xb1\\\\xd7\\\\xf7\\\\x00-\\\\x2f\\\\x3a-\\\\x40\\\\x5b-\\\\x60\\\\x7b-\\\\xbf\\\\u2000-\\\\u206f '
#                          '\\\\t\\\\x0b\\\\f\\\\xa0\\\\ufeff\\\\n\\\\r\\\\u2028\\\\u2029\\\\u1680\\\\u180e\\\\u2000\\\\u2001\\\\u2002\\\\u2003\\\\u2004\\\\u2005\\\\u2006\\\\u2007\\\\u2008\\\\u2009\\\\u200a\\\\u202f\\\\u205f\\\\u3000",u="[\\\\ud800-\\\\udfff]",o="["+i+"]",c="[\\\\u0300-\\\\u036f\\\\ufe20-\\\\ufe23\\\\u20d0-\\\\u20f0]",a="\\\\d+",f="[\\\\u2700-\\\\u27bf]",d="[a-z\\\\xdf-\\\\xf6\\\\xf8-\\\\xff]",s="[^\\\\ud800-\\\\udfff"+i+a+"\\\\u2700-\\\\u27bfa-z\\\\xdf-\\\\xf6\\\\xf8-\\\\xffA-Z\\\\xc0-\\\\xd6\\\\xd8-\\\\xde]",l="\\\\ud83c[\\\\udffb-\\\\udfff]",p="[^\\\\ud800-\\\\udfff]",_="(?:\\\\ud83c[\\\\udde6-\\\\uddff]){2}",y="[\\\\ud800-\\\\udbff][\\\\udc00-\\\\udfff]",b="[A-Z\\\\xc0-\\\\xd6\\\\xd8-\\\\xde]",h="(?:"+d+"|"+s+")",g="(?:"+b+"|"+s+")",v="(?:"+c+"|"+l+")"+"?",m="[\\\\ufe0e\\\\ufe0f]?"+v+("(?:\\\\u200d(?:"+[p,_,y].join("|")+")[\\\\ufe0e\\\\ufe0f]?"+v+")*"),x="(?:"+[f,_,y].join("|")+")"+m,w="(?:"+[p+c+"?",c,_,y,u].join("|")+")",E=RegExp("[\'\\u2019]","g"),S=RegExp(c,"g"),C=RegExp(l+"(?="+l+")|"+w+m,"g"),A=RegExp([b+"?"+d+"+(?:[\'\\u2019](?:d|ll|m|re|s|t|ve))?(?="+[o,b,"$"].join("|")+")",g+"+(?:[\'\\u2019](?:D|LL|M|RE|S|T|VE))?(?="+[o,b+h,"$"].join("|")+")",b+"?"+h+"+(?:[\'\\u2019](?:d|ll|m|re|s|t|ve))?",b+"+(?:[\'\\u2019](?:D|LL|M|RE|S|T|VE))?",a,x].join("|"),"g"),k=RegExp("[\\\\u200d\\\\ud800-\\\\udfff\\\\u0300-\\\\u036f\\\\ufe20-\\\\ufe23\\\\u20d0-\\\\u20f0\\\\ufe0e\\\\ufe0f]"),O=/[a-z][A-Z]|[A-Z]{2,}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 '
#                          ']/,L="object"==typeof '
#                          't&&t&&t.Object===Object&&t,j="object"==typeof '
#                          'self&&self&&self.Object===Object&&self,P=L||j||Function("return '
#                          'this")();var R=function basePropertyOf(e){return '
#                          'function(t){return null==e?void '
# ...
#                          'B=this;B[l]=A;B.handlers={};A.onsubmit=function(){return '
#                          'A[b].onsubmit_handler()};A.onreset=function(){return '
#                          'A[b].onreset_handler()};B[f]=k.default_invalid_field_handler}d.prototype={add_handler:function(B,A){var '
#                          'C=this.handlers[B];if(!C){C=[];this.handlers[B]=C}C.push(A)},invoke_handlers:function(B,D){if(D[r]){return}var '
#                          'E=this.handlers[B];if(!E){return}var '
#                          'C=E.length,A=0;for(;A<C;A++){E[A].call(window,D);if(D[r]){return}}},add_cancel_handler:function(A){this[a](e,A)},cancel:function(){var '
#                          'C=this,B=C[l],A=new '
#                          'v(B,e,C[f]);C.invoke_handlers(e,A);if(A[s]===false){B[t][i]=e;B[w]=null;B[y]()}},add_presubmit_handler:function(A){this[a](o,A)},add_submit_handler:function(A){this[a](y,A)},add_postsubmit_handler:function(A){this[a](q,A)},submit:function(A){var '
#                          'C=this,B=C[l];if(C.onsubmit_handler()){B[w]=null;B[h][i]=A;B[y]()}},onsubmit_handler:function(){var '
#                          'C=this,B=C[l],A=new '
#                          'v(B,y,C[f]);C.invoke_handlers(o,A);C.invoke_handlers(y,A);C.invoke_handlers(q,A);if(A[s]){return '
#                          'false}B[t][i]=y;B[h][i]=z;return '
#                          'true},add_refresh_handler:function(A){this[a](y,A);this[a](u,A)},refresh:function(A){var '
#                          'D=this,C=D[l],B=new '
#                          'v(C,u,D[f]);D.invoke_handlers(u,B);if(B[s]){return}C[t][i]=u;C[h][i]=A;C[w]=null;C[y]()},add_reset_handler:function(A){this[a](n,A)},onreset_handler:function(){var '
#                          'B=this,A=new '
#                          'v(B[l],n,B[f]);B.invoke_handlers(n,A);return '
#                          '!A[s]}};this.Tapestry=k}());</script><script '
#                          'language="JavaScript" type="text/javascript"><!--\n'
#                          'if(!window.ZMOB_nativeAPI||(window.ZMOB_nativeAPI&&!window.ZMOB_nativeAPI.trackWebviewEvent)){(function(){window._gaq=window._gaq||[];window._gaqBackup=window._gaqBackup||[];window._gaq.push(["_setAccount","UA-21174015-1"]);window._gaq.push(["_setDomainName",".zillow.com"]);window._gaqBackup=[["_setCustomVar",6,"Zip",""],["_setCustomVar",8,"Address",""],["_setCustomVar",22,"AccountCreationDate","",1],["_setCustomVar",1,"Guid","b798348d465144e09675447d3f0851a1",1],["_setCustomVar",146,"RegionID","40"],["_setCustomVar",66,"PageType","Search"],["_setCustomVar",5,"City",""],["_setCustomVar",164,"A/B '
#                          'Test '
#                          '26","IOS_SH_TOUR_CTA.CONTROL",1],["_setCustomVar",165,"A/B '
#                          'Test '
#                          '27","CW_CONTACT_FORM_SUPPORT_MANUFACTURED.CONTROL",1],["_setCustomVar",7,"Neighborhood",""],["_setCustomVar",168,"A/B '
#                          'Test '
#                          '30","CW_FINANCE_WITH_INLINE_WEB.THREE_VARIANT",1],["_setCustomVar",169,"A/B '
#                          'Test '
#                          '31","CW_HIGH_INTENT_PHONE_ANDROID.CONTROL",1],["_setCustomVar",25,"Device '
#                          'Type","Desktop"],["_setCustomVar",197,"searchListZpids","[38780055, '
#                          '38792874, 38800662, 38856743, 38961051, 38967482, '
#                          '39101762, 39106917, 39136677, 39155788, 39160586, '
#                          '39279041, 39503956, 39549269, 39650502, 39700034, '
#                          '39967724, 39992301, 52404678, 52668672, 52889274, '
#                          '54677880, 61837933, 61857105, 61859615, 63678608, '
#                          '65012853, 68303256, 70161453, 70163830, 87972986, '
#                          '37845034, 38232930, 2062665853, 2066501235, '
#                          '2060691659, 38155595, 38801661, 39524155, '
#                          '39954928]"],["_setCustomVar",166,"A/B Test '
#                          '28","CW_HIGH_INTENT_PHONE_MWEB.CONTACT_FORM_LOCAL",1],["_setCustomVar",167,"A/B '
#                          'Test '
#                          '29","WEB_HIDDEN_HOMES_2022.ON",1],["_setCustomVar",92,"SEO '
#                          'Test '
#                          '3","SEOTEST__RE_Add_BuildingOverview_SRP.CONTROL",1],["_setCustomVar",3,"State","NJ"],["_setCustomVar",90,"SEO '
#                          'Test '
#                          '1","SEOTEST__SRP_PAGINATION.CONTROL",1],["_setCustomVar",23,"SearchTypes","ForSale",2],["_setCustomVar",12,"UserType","Unrecognized",2],["_setCustomVar",60,"A/B '
#                          'Test '
#                          '20","CW_HIGH_INTENT_PHONE_DESKTOP.LOW_HDP_NATIONAL",1],["_setCustomVar",171,"A/B '
#                          'Test '
#                          '33","SXP_MULTIREGION_SEARCH.CONTROL",1],["_setCustomVar",172,"A/B '
#                          'Test '
#                          '34","HDP_INSIGHTS_VERSION.CONTROL",1],["_setCustomVar",170,"A/B '
#                          'Test '
#                          '32","LEAD_PACING_PALS_API_SWITCHOVER.ON",1],["_setCustomVar",175,"A/B '
#                          'Test '
#                          '37","HDP_DEEP_DIVE_REORDER.VARIANT_A",1],["_setCustomVar",4,"County",""],["_setCustomVar",176,"A/B '
#                          'Test '
#                          '38","AB_DASHBOARD_AA_TEST.CONTROL",1],["_setCustomVar",173,"A/B '
#                          'Test '
#                          '35","VL_LAYOUT.CONTROL",1],["_setCustomVar",174,"A/B '
#                          'Test '
#                          '36","HDP_DEEP_DIVE_REORDER_APP.CONTROL",1],["_setCustomVar",179,"A/B '
#                          'Test '
#                          '41","SP_OFF_MARKET_PAGE.CONTROL",1],["_setCustomVar",177,"A/B '
#                          'Test '
#                          '39","AIPERS_COLLECTIONS_UPDATES_TAB.APP_D",1],["_setCustomVar",178,"A/B '
#                          'Test '
#                          '40","ZHL_PREQUAL_CTAS.CONTROL",1],["_setCustomVar",58,"A/B '
#                          'Test '
#                          '18","ANDROID_NATIVE_STANDARD_TOUR_FORM_SLICE_B_FOLLOWUP.CONTROL",1],["_setCustomVar",59,"A/B '
#                          'Test '
#                          '19","DXP_CONST_PROPCARD_MAPVIEW.CONTROL",1],["_setCustomVar",39,"A/B '
#                          'Test '
#                          '14","RMX_AGENT_PROMINENCE.CONTROL",1],["_setCustomVar",40,"A/B '
#                          'Test '
#                          '15","RE_NON_VARIANT_HDP_DEFERRED_HYDRATION.TEST",1],["_setCustomVar",56,"A/B '
#                          'Test '
#                          '16","AuthN_VerifyMailReg.CONTROL",1],["_setCustomVar",57,"A/B '
#                          'Test '
#                          '17","IOS_NATIVE_TOUR_FORM_TREATMENT.CONTROL",1],["_setCustomVar",50,"A/B '
#                          'Test '
#                          '10","DXP_NEW_MAP_DOTS_WEB.CONTROL",1],["_setCustomVar",36,"A/B '
#                          'Test '
#                          '11","VL_RENTAL_DATA_API.CONTROL",1],["_setCustomVar",37,"A/B '
#                          'Test '
#                          '12","ANDROID_PHOTO_CAROUSEL.CONTROL_PHOTO_CAROUSEL",1],["_setCustomVar",38,"A/B '
#                          'Test '
#                          '13","IOS_MONTHLY_COST_FILTER_MVP.ON",1],["_setCustomVar",158,"RegionTrialType","USER"],["_setCustomVar",70,"InternalSearchTerm","NJ"],["_setCustomVar",182,"A/B '
#                          'Test '
#                          '44","CW_HIGH_INTENT_PHONE_IOS.CONTROL",1],["_setCustomVar",183,"A/B '
#                          'Test '
#                          '45","RE_HDP_REDIRECT.TEST",1],["_setCustomVar",180,"A/B '
#                          'Test '
#                          '42","ONSITE_MESSAGE_VALVE.OMP_ON",1],["_setCustomVar",159,"UserFirstVisitTrialTypes",""],["_setCustomVar",181,"A/B '
#                          'Test '
#                          '43","IOS_PHOTO_CAROUSEL.CONTROL_OFF",1],["_setCustomVar",18,"SearchScenario","Region-State"],["_setCustomVar",186,"A/B '
#                          'Test '
#                          '48","AIPERS_HIDE_HOMES.CONTROL",1],["_setCustomVar",187,"A/B '
#                          'Test '
#                          '49","HDP_MEDIASOLUTIONS_ADS_WEB_PROG.CONTROL",1],["_setCustomVar",184,"A/B '
#                          'Test '
#                          '46","IOS_NATIVE_SHARE_SHEET.ON",1],["_setCustomVar",185,"A/B '
#                          'Test '
#                          '47","ARCS_INSTANT_BOOK.ON",1],["_setCustomVar",71,"SortType","pricea"],["_setCustomVar",188,"A/B '
#                          'Test '
#                          '50","ZEXP_DECISION_TOKEN_HOLD.wTD5b4_1670570165",1],["_setCustomVar",69,"FullReferringURL",""],["_setCustomVar",49,"A/B '
#                          'Test '
#                          '9","AR_MY_AGENT_POST_SUBMIT_MIGRATION_MOBILE.CONTROL",1],["_setCustomVar",46,"A/B '
#                          'Test '
#                          '6","SXP_VISUAL_AUDIT_2021.CONTROL",1],["_setCustomVar",45,"A/B '
#                          'Test '
#                          '5","IOS_OMHDP_NATIVE_HOMEVALUE.CONTROL_OFF",1],["_setCustomVar",48,"A/B '
#                          'Test '
#                          '8","DXP_PHOTO_CAROUSEL.CONTROL",1],["_setCustomVar",47,"A/B '
#                          'Test '
#                          '7","SXP_Search_Refinement_Filters.FILTERS_ON",1],["_setCustomVar",61,"A/B '
#                          'Test '
#                          '21","LEGO_RENTALS_COMPARISON_TOOL.CONTROL",1],["_setCustomVar",41,"A/B '
#                          'Test '
#                          '1","RE_contacted_hdp_bdp.AA_VARIANT",1],["_setCustomVar",62,"A/B '
#                          'Test '
#                          '22","AIPERS_COLLECTIONS_GEOLOCATION.CONTROL",1],["_setCustomVar",44,"A/B '
#                          'Test '
#                          '4","AR_MY_AGENT_RECONNECTIONS_LOGGED_OUT_OPAQUE.ON",1],["_setCustomVar",63,"A/B '
#                          'Test '
#                          '23","DXP_SEE_MORE_RECS.SCROLL_ON",1],["_setCustomVar",64,"A/B '
#                          'Test '
#                          '24","ADAT_APS_EMPTY_CLIENT_INFO.CONTROL_DASH",1],["_setCustomVar",68,"FullURL","https://www.zillow.com/nj/2_p/?searchQueryState=%7B%22pagination%22:%7B%22currentPage%22:2%7D,%22usersSearchTerm%22:%22NJ%22,%22mapBounds%22:%7B%22west%22:-76.7952458515625,%22east%22:-72.6534001484375,%22south%22:38.68416008936318,%22north%22:41.45789958695567%7D,%22regionSelection%22:%5B%7B%22regionId%22:40,%22regionType%22:2%7D%5D,%22isMapVisible%22:true,%22filterState%22:%7B%22mp%22:%7B%22min%22:1436%7D,%22sort%22:%7B%22value%22:%22pricea%22%7D,%22ah%22:%7B%22value%22:true%7D,%22price%22:%7B%22min%22:300000%7D%7D,%22isListVisible%22:true,%22mapZoom%22:8%7D"],["_trackPageview","/nj/2_p/"]];window._gaq.push.apply(window._gaq,window._gaqBackup)})();(function(h,g,f,c,i){var '
#                          'd={};var e=[];var '
#                          'a=false;d[c]=true;h[i]=function(j){if(a){j()}else{e.push(j)}};function '
#                          'b(){a=true;e.forEach(function(j){j()});e=[]}d.end=b;(h[g]=h[g]||[]).hide=d;setTimeout(function(){if(!a){console.warn("Google '
#                          'Optimize '
#                          'timeout")}b();d.end=null},(d.timeout=f));h.__checkRealGAFallback=function(){if(!h.ga){b()}else{if(h.ga.create.toString().indexOf("Tracker")>=0){b()}}}}(window,"dataLayer",4000,"GTM-WQL55SH","__onOptimizeLoaded"));(function(){window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new '
#                          'Date;var '
#                          'a=[];ga("create","UA-21174015-56","auto",{allowLinker:true});ga("require","GTM-WQL55SH");ga("require","linker");ga("linker:autoLink",["trulia.com"]);ga("set",{dimension90:"SEOTEST__SRP_PAGINATION.CONTROL",dimension197:"[38780055, '
#                          '38792874, 38800662, 38856743, 38961051, 38967482, '
#                          '39101762, 39106917, 39136677, 39155788, 39160586, '
#                          '39279041, 39503956, 39549269, 39650502, 39700034, '
#                          '39967724, 39992301, 52404678, 52668672, 52889274, '
#                          '54677880, 61837933, 61857105, 61859615, 63678608, '
#                          '65012853, 68303256, 70161453, 70163830, 87972986, '
#                          '37845034, 38232930, 2062665853, 2066501235, '
#                          '2060691659, 38155595, 38801661, 39524155, '
#                          '39954928]",dimension92:"SEOTEST__RE_Add_BuildingOverview_SRP.CONTROL",dimension70:"NJ",dimension146:"40",dimension158:"USER",dimension23:"ForSale",dimension12:"Unrecognized",dimension66:"Search",dimension71:"pricea",dimension18:"Region-State",metric1:"2",metric2:"40",metric3:"14360",dimension25:"Desktop",dimension3:"NJ"});zanalytics.setdim({dimension90:"SEOTEST__SRP_PAGINATION.CONTROL",dimension197:"[38780055, '
#                          '38792874, 38800662, 38856743, 38961051, 38967482, '
#                          '39101762, 39106917, 39136677, 39155788, 39160586, '
#                          '39279041, 39503956, 39549269, 39650502, 39700034, '
#                          '39967724, 39992301, 52404678, 52668672, 52889274, '
#                          '54677880, 61837933, 61857105, 61859615, 63678608, '
#                          '65012853, 68303256, 70161453, 70163830, 87972986, '
#                          '37845034, 38232930, 2062665853, 2066501235, '
#                          '2060691659, 38155595, 38801661, 39524155, '
#                          '39954928]",dimension92:"SEOTEST__RE_Add_BuildingOverview_SRP.CONTROL",dimension70:"NJ",dimension146:"40",dimension158:"USER",dimension23:"ForSale",dimension12:"Unrecognized",dimension66:"Search",dimension71:"pricea",dimension18:"Region-State",metric1:"2",metric2:"40",metric3:"14360",dimension25:"Desktop",dimension3:"NJ"});ga("send","pageview","/nj/2_p/");zanalytics.page("/nj/2_p/");ga.q=ga.q||[];ga.q=ga.q.concat(a)}());ga("set","userId","");window.optimizely=window.optimizely||[];window.optimizely.push("activateUniversalAnalytics")};\n'
#                          'var '
#                          '_comscore=_comscore||[];_comscore.push({c1:2,c2:"6036206",c3:"",c4:"www.zillow.com/nj/2_p/",c5:"",c6:"",c15:""});var '
#                          '_comscoreBackup=_comscoreBackup||[];_comscoreBackup.push.apply(_comscoreBackup,_comscore);setTimeout(function(){var '
#                          'b=document.createElement("script");b.type="text/javascript";b.setAttribute("async",true);b.src=(document.location.protocol=="https:"?"https://sb":"http://b")+".scorecardresearch.com/beacon.js";var '
#                          'a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)},100);\n'
#                          '\n'
#                          '// --></script></body>\n'
#                          '</html><!-- H:029  T:329ms  S:607503  R:Thu Dec 08 '
#                          '23:16:05 PST 2022  '
#                          'B:5.0.69871-master.db01204~qa,spring_4_pre.435ff78e '
#                          '-->',
#               'created_at': '2022-12-09 07:16:03',
#               'job_id': '7006879120743249921',
#               'page': 1,
#               'session_info': {'expires_at': None,
#                                'id': None,
#                                'remaining': None},
#               'status_code': 200,
#               'updated_at': '2022-12-09 07:16:07',
#               'url': 'https://www.zillow.com/nj/2_p/?searchQueryState=%7B%22pagination%22:%7B%22currentPage%22:2%7D,%22usersSearchTerm%22:%22NJ%22,%22mapBounds%22:%7B%22west%22:-76.7952458515625,%22east%22:-72.6534001484375,%22south%22:38.68416008936318,%22north%22:41.45789958695567%7D,%22regionSelection%22:%5B%7B%22regionId%22:40,%22regionType%22:2%7D%5D,%22isMapVisible%22:true,%22filterState%22:%7B%22mp%22:%7B%22min%22:1436%7D,%22sort%22:%7B%22value%22:%22pricea%22%7D,%22ah%22:%7B%22value%22:true%7D,%22price%22:%7B%22min%22:300000%7D%7D,%22isListVisible%22:true,%22mapZoom%22:8%7D'}]}

# %%
print(data1)
# Out:
# None

# %%
# Structure payload.
payload = {
    "source": "universal",
    "url": "https://www.zillow.com/nj/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22usersSearchTerm%22%3A%22NJ%22%2C%22mapBounds%22%3A%7B%22west%22%3A-76.7952458515625%2C%22east%22%3A-72.6534001484375%2C%22south%22%3A38.68416008936318%2C%22north%22%3A41.45789958695567%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A40%2C%22regionType%22%3A2%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22mp%22%3A%7B%22min%22%3A1436%7D%2C%22sort%22%3A%7B%22value%22%3A%22pricea%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22price%22%3A%7B%22min%22%3A300000%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A8%7D"
,
    #"render": "html", # If page type requires
}

# Get response.
response = requests.request(
    'POST',
    'https://realtime.oxylabs.io/v1/queries',
    auth=('scatw2022116dan9232', 'ZjkawIChtB'), #Your credentials go here
    json=payload,
)
store.append(response.json())

# %%
'''
{'results': [{'_request': {'cookies': [],
                           'headers': {'Accept': 'text/html,application/xhtml+xml,image/jxr,*/*',
                                       'Accept-Encoding': 'gzip,deflate',
                                       'Accept-Language': 'en-US,en;q=0.7',
                                       'Connection': 'Keep-Alive',
                                       'User-Agent': 'Mozilla/5.0 (Windows NT '
                                                     '10.0; Win64; x64) '
                                                     'AppleWebKit/537.36 '
                                                     '(KHTML like Gecko) '
                                                     'Chrome/83.0.4103.116 '
                                                     'Safari/537.36 '
                                                     'Edg/83.0.478.64'}},
              '_response': {'cookies': [{'comment': '',
                                         'domain': '',
                                         'expires': 'Fri, 16 Dec 2022 07:16:05 '
                                                    'GMT',
                                         'httponly': '',
                                         'key': 'AWSALB',
                                         'max-age': '',
                                         'path': '/',
                                         'samesite': '',
                                         'secure': '',
                                         'value': '8++ua9oudp3x75KZAjtAqeC1IaWLBZrETIriXmPkOSMgTQ7Rci/TgrCpBjU/h0CGo7HDPNXj7oYAwffPeNfPx8f+syo7QxNVf8PzmW/J054jGOUnS/l3kg+pEioW',
                                         'version': ''},
                                        {'comment': '',
                                         'domain': '',
                                         'expires': 'Fri, 16 Dec 2022 07:16:05 '
                                                    'GMT',
                                         'httponly': '',
                                         'key': 'AWSALBCORS',
                                         'max-age': '',
                                         'path': '/',
                                         'samesite': 'None',
                                         'secure': True,
                                         'value': '8++ua9oudp3x75KZAjtAqeC1IaWLBZrETIriXmPkOSMgTQ7Rci/TgrCpBjU/h0CGo7HDPNXj7oYAwffPeNfPx8f+syo7QxNVf8PzmW/J054jGOUnS/l3kg+pEioW',
                                         'version': ''},
                                        {'comment': '',
                                         'domain': '',
                                         'expires': '',
                                         'httponly': True,
                                         'key': 'JSESSIONID',
                                         'max-age': '',
                                         'path': '/',
                                         'samesite': '',
                                         'secure': True,
                                         'value': '0F2F26FE61220184D629419AAF80AC09',
                                         'version': ''},
                                        {'comment': '',
                                         'domain': '.zillow.com',
                                         'expires': 'Wed, 08-Dec-2032 19:16:05 '
                                                    'GMT',
                                         'httponly': '',
                                         'key': 'search',
                                         'max-age': '',
                                         'path': '/',
                                         'samesite': '',
                                         'secure': '',
                                         'value': '6|1673162165016%7Cregion%3Dnj%26rect%3D41.357423%252C-73.88506%252C38.788657%252C-75.563586%26p%3D2%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%09%0940%09%09%09%09%09%09',
                                         'version': ''},
                                        {'comment': '',
                                         'domain': '.zillow.com',
                                         'expires': 'Wed, 8 Dec 2032 19:16:05 '
                                                    'GMT',
                                         'httponly': '',
                                         'key': 'zguid',
                                         'max-age': '315576000',
                                         'path': '/',
                                         'samesite': '',
                                         'secure': '',
                                         'value': '24|%24b798348d-4651-44e0-9675-447d3f0851a1',
                                         'version': ''},
                                        {'comment': '',
                                         'domain': '.zillow.com',
                                         'expires': '',
                                         'httponly': True,
                                         'key': 'zgsession',
                                         'max-age': '',
                                         'path': '/',
                                         'samesite': '',
                                         'secure': '',
                                         'value': '1|1c874320-8046-4fb5-b1e1-2fc2aa68aaf5',
                                         'version': ''}],
                            'headers': {'alt-svc': 'h3=":443"; ma=86400',
                                        'cache-control': 'no-cache',
                                        'content-encoding': 'gzip',
                                        'content-security-policy': 'frame-ancestors '
                                                                   'zillow.highspot.com '
                                                                   'view.highspot.com;',
                                        'content-type': 'text/html;charset=UTF-8',
                                        'date': 'Fri, 09 Dec 2022 07:16:05 GMT',
                                        'expires': 'Thu, 01 Jan 1970 00:00:00 '
                                                   'GMT',
                                        'server': 'Apache-Coyote/1.1',
                                        'vary': 'Accept-Encoding',
                                        'via': '1.1 zgs, 1.1 '
                                               '6fc1853aec8424fa9c4a2f1e81f20780.cloudfront.net '
                                               '(CloudFront)',
                                        'x-amz-cf-id': 'j6MgLeAhlLztQodfw7Rgxqpl3y1k6D10G6wtjtT7pODvzTUiIJCWLw==',
                                        'x-amz-cf-pop': 'SOF50-C1',
                                        'x-cache': 'Miss from cloudfront',
                                        'x-frame-options': 'deny',
                                        'x-internal-host': '029',
                                        'z-using-act': '2'}},
'''
# Out:
# '\n{\'results\': [{\'_request\': {\'cookies\': [],\n                           \'headers\': {\'Accept\': \'text/html,application/xhtml+xml,image/jxr,*/*\',\n                                       \'Accept-Encoding\': \'gzip,deflate\',\n                                       \'Accept-Language\': \'en-US,en;q=0.7\',\n                                       \'Connection\': \'Keep-Alive\',\n                                       \'User-Agent\': \'Mozilla/5.0 (Windows NT \'\n                                                     \'10.0; Win64; x64) \'\n                                                     \'AppleWebKit/537.36 \'\n                                                     \'(KHTML like Gecko) \'\n                                                     \'Chrome/83.0.4103.116 \'\n                                                     \'Safari/537.36 \'\n                                                     \'Edg/83.0.478.64\'}},\n              \'_response\': {\'cookies\': [{\'comment\': \'\',\n                                         \'domain\': \'\',\n                                         \'expires\': \'Fri, 16 Dec 2022 07:16:05 \'\n                                                    \'GMT\',\n                                         \'httponly\': \'\',\n                                         \'key\': \'AWSALB\',\n                                         \'max-age\': \'\',\n                                         \'path\': \'/\',\n                                         \'samesite\': \'\',\n                                         \'secure\': \'\',\n                                         \'value\': \'8++ua9oudp3x75KZAjtAqeC1IaWLBZrETIriXmPkOSMgTQ7Rci/TgrCpBjU/h0CGo7HDPNXj7oYAwffPeNfPx8f+syo7QxNVf8PzmW/J054jGOUnS/l3kg+pEioW\',\n                                         \'version\': \'\'},\n                                        {\'comment\': \'\',\n                                         \'domain\': \'\',\n                                         \'expires\': \'Fri, 16 Dec 2022 07:16:05 \'\n                                                    \'GMT\',\n                                         \'httponly\': \'\',\n                                         \'key\': \'AWSALBCORS\',\n                                         \'max-age\': \'\',\n                                         \'path\': \'/\',\n                                         \'samesite\': \'None\',\n                                         \'secure\': True,\n                                         \'value\': \'8++ua9oudp3x75KZAjtAqeC1IaWLBZrETIriXmPkOSMgTQ7Rci/TgrCpBjU/h0CGo7HDPNXj7oYAwffPeNfPx8f+syo7QxNVf8PzmW/J054jGOUnS/l3kg+pEioW\',\n                                         \'version\': \'\'},\n                                        {\'comment\': \'\',\n                                         \'domain\': \'\',\n                                         \'expires\': \'\',\n                                         \'httponly\': True,\n                                         \'key\': \'JSESSIONID\',\n                                         \'max-age\': \'\',\n                                         \'path\': \'/\',\n                                         \'samesite\': \'\',\n                                         \'secure\': True,\n                                         \'value\': \'0F2F26FE61220184D629419AAF80AC09\',\n                                         \'version\': \'\'},\n                                        {\'comment\': \'\',\n                                         \'domain\': \'.zillow.com\',\n                                         \'expires\': \'Wed, 08-Dec-2032 19:16:05 \'\n                                                    \'GMT\',\n                                         \'httponly\': \'\',\n                                         \'key\': \'search\',\n                                         \'max-age\': \'\',\n                                         \'path\': \'/\',\n                                         \'samesite\': \'\ ...

# %%
s
